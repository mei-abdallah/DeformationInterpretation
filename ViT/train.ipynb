# %%
from Network import Trainer

# %%
trainer = Trainer(datadir='../Dataset/Real', backbone='vit_tiny_patch16_224', num_classes=4, num_locations=0, batch_size=4, freeze=True, pretrained=True)
# Out:
# seed was set manually to [42]
# start time: 2024_08_01_18_42_51
# attached Devices: cpu

# %%
trainer.fit(2, lambdaCLSQuality=2.0, lambdaPOSQuality=1.0)
# Out:
# Training epoch: 001
# 6/6 [====================] - 2s 352ms/step - epoch: 1 - cls_loss: 3.1835 - acc: 0.0000 - loss: 6.3669
# Validating epoch: 001
# 6/6 [====================] - 2s 358ms/step - epoch: 1 - val_cls_loss: 3.0355 - val_acc: 0.0000 - val_loss: 6.0710
# Epoch: [001] | metric `val_loss` improved from inf to 6.2066
# Epoch: [001/2] | loss = 7.2555, val_loss = 6.2066, cls_loss = 3.6277, val_cls_loss = 3.1033, acc = 0.0000, val_acc = 0.0000
# Saving checkpoint to ./CheckPoints/2024_08_01_18_42_51/ViT.pth
# Training epoch: 002
# 6/6 [====================] - 2s 364ms/step - epoch: 2 - cls_loss: 2.3319 - acc: 0.0000 - loss: 4.6638
# Validating epoch: 002
# 6/6 [====================] - 2s 369ms/step - epoch: 2 - val_cls_loss: 2.1976 - val_acc: 0.0000 - val_loss: 4.3953
# Epoch: [002] | metric `val_loss` improved from 6.2066 to 4.5169
# Epoch: [002/2] | loss = 5.4913, val_loss = 4.5169, cls_loss = 2.7456, val_cls_loss = 2.2584, acc = 0.0000, val_acc = 0.0000
# ...
