# %%
from Network import Trainer

# %%
trainer = Trainer(datadir='../Dataset/Real', backbone='resnet18', num_classes=4, num_locations=0, batch_size=4, freeze=True, pretrained=True)
# Out:
# seed was set manually to [42]
# start time: 2024_08_01_18_41_48
# attached Devices: cpu

# %%
trainer.fit(2, lambdaCLSQuality=2.0, lambdaPOSQuality=1.0)
# Out:
# Training epoch: 001
# 6/6 [====================] - 2s 370ms/step - epoch: 1 - cls_loss: 1.0872 - acc: 0.5000 - loss: 2.1744
# Validating epoch: 001
# 6/6 [====================] - 2s 357ms/step - epoch: 1 - val_cls_loss: 1.6850 - val_acc: 0.0000 - val_loss: 3.3700
# Epoch: [001] | metric `val_loss` improved from inf to 3.4748
# Epoch: [001/2] | loss = 2.8186, val_loss = 3.4748, cls_loss = 1.4093, val_cls_loss = 1.7374, acc = 0.2083, val_acc = 0.0000
# Saving checkpoint to ./CheckPoints/2024_08_01_18_41_48/CNN.pth
# Training epoch: 002
# 6/6 [====================] - 2s 367ms/step - epoch: 2 - cls_loss: 0.5783 - acc: 1.0000 - loss: 1.1566
# Validating epoch: 002
# 6/6 [====================] - 2s 367ms/step - epoch: 2 - val_cls_loss: 0.5129 - val_acc: 0.7500 - val_loss: 1.0258
# Epoch: [002] | metric `val_loss` improved from 3.4748 to 1.2135
# Epoch: [002/2] | loss = 1.5197, val_loss = 1.2135, cls_loss = 0.7598, val_cls_loss = 0.6068, acc = 0.9167, val_acc = 0.8333
# ...
